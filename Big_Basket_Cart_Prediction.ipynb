# %% [markdown]
# Importing Libraries
# bold text

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.7/dist-packages (1.1.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Import dataset**

# %%
dataset = pd.read_csv("Big Basket Cart Prediction.csv", header= None)
transactions = []
for i in range(0, 7219):
  transactions.append([str(dataset.values[i,j]) for j in range(0,20)])

# %% [markdown]
# **Apriori training on dataset**

# %%
from apyori import apriori
basket_intelligence = apriori( transactions= transactions, min_support = 0.002, min_confidence = 0.2, min_lift= 3, min_length= 2)

# %% [markdown]
# **Visualizing**

# %% [markdown]
# **Raw results**

# %%
results= list(basket_intelligence)

# %%
print(results)
# Out:
# [RelationRecord(items=frozenset({'5 star', 'pancakes'}), support=0.0022163734589278295, ordered_statistics=[OrderedStatistic(items_base=frozenset({'5 star'}), items_add=frozenset({'pancakes'}), confidence=0.326530612244898, lift=3.446234634204559)]), RelationRecord(items=frozenset({'MTR Idli', 'parle g'}), support=0.00207785011774484, ordered_statistics=[OrderedStatistic(items_base=frozenset({'MTR Idli'}), items_add=frozenset({'parle g'}), confidence=0.2631578947368421, lift=3.247413405308142)]), RelationRecord(items=frozenset({'almonds', 'burgers'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.26530612244897955, lift=3.0594966421073218)]), RelationRecord(items=frozenset({'turkey', 'barbecue sauce'}), support=0.002493420141293808, ordered_statistics=[OrderedStatistic(items_base=frozenset({'barbecue sauce'}), items_add=frozenset({'turkey'}), confidence=0.22499999999999998, lift=3.585596026490066)]), RelationRecord(items=frozenset({'buns', 'paneer'}), support=0.016068707577226764, ordered_statistics=[OrderedStatistic(items_base=frozenset({'buns'}), items_add=frozenset({'paneer'}), confidence=0.32402234636871513, lift=3.2852771326344867)]), RelationRecord(items=frozenset({'cadbury white chocolate', 'chicken'}), support=0.0027704668236597867, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cadbury white chocolate'}), items_add=frozenset({'chicken'}), confidence=0.22988505747126436, lift=3.7716823406478577)]), RelationRecord(items=frozenset({'cadbury white chocolate', 'olive oil'}), support=0.0027704668236597867, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cadbury white chocolate'}), items_add=frozenset({'olive oil'}), confidence=0.22988505747126436, lift=3.501139725495902)]), RelationRecord(items=frozenset({'chicken', 'ginger garlic paste'}), support=0.004571270259038648, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ginger garlic paste'}), items_add=frozenset({'chicken'}), confidence=0.29203539823008845, lift=4.791371681415929)]), RelationRecord(items=frozenset({'fruit basket', 'vegetable basket'}), support=0.0055409336473195734, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fruit basket'}), items_add=frozenset({'vegetable basket'}), confidence=0.29411764705882354, lift=3.081618714249125)]), RelationRecord(items=frozenset({'ginger garlic paste', 'olive oil'}), support=0.003324560188391744, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ginger garlic paste'}), items_add=frozenset({'olive oil'}), confidence=0.21238938053097342, lift=3.2346813039094875)]), RelationRecord(items=frozenset({'paneer', 'kissan puree'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'kissan puree'}), items_add=frozenset({'paneer'}), confidence=0.3786407766990291, lift=3.8390558525144542)]), RelationRecord(items=frozenset({'pasta', 'maggi'}), support=0.0034630835295747335, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'maggi'}), confidence=0.24752475247524755, lift=3.4562498803071797)]), RelationRecord(items=frozenset({'pasta', 'mushroom'}), support=0.005402410306136584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'mushroom'}), confidence=0.38613861386138615, lift=4.873312331233124)]), RelationRecord(items=frozenset({'mushroom', 'pepper spray'}), support=0.005817980329685552, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pepper spray'}), items_add=frozenset({'mushroom'}), confidence=0.3021582733812949, lift=3.8134275796146295)]), RelationRecord(items=frozenset({'neckrest', 'trolly bag'}), support=0.0034630835295747335, ordered_statistics=[OrderedStatistic(items_base=frozenset({'neckrest'}), items_add=frozenset({'trolly bag'}), confidence=0.2717391304347826, lift=5.620873302603712)]), RelationRecord(items=frozenset({'whole wheat pasta', 'ol ...

# %% [markdown]
# **Display**

# %%
def inspect(results):
  product1 =    [tuple(result[2][0][0])[0] for result in results]
  product2 =    [tuple(result[2][0][1])[0] for result in results]
  supports =    [result[1] for result in results]
  confidence =  [result[2][0][2] for result in results]
  lift =       [result[2][0][3] for result in results]
  return list(zip( product1, product2, supports, confidence, lift))
DataFrame_intelligence = pd.DataFrame(inspect(results), columns= ['Product1', 'Product2', 'supports', 'Confidence', 'Lift'])

# %%
DataFrame_intelligence
# Out:
#              Product1          Product2  supports  Confidence       Lift
# 145             pasta      pepper spray  0.002493    0.461538  23.970116
# 373             pasta      pepper spray  0.002493    0.461538  23.970116
# 489          tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 391          tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 420         chocolate     mineral water  0.002078    0.326087   9.019240
# ..                ...               ...       ...         ...        ...
# 123  vegetable basket             maggi  0.006095    0.215686   3.011681
# 65            chicken            paneer  0.002216    0.296296   3.004161
# 221           chicken               nan  0.002216    0.296296   3.004161
# 384            salmon               nan  0.004017    0.295918   3.000330
# 158            salmon            paneer  0.004017    0.295918   3.000330
#
# [492 rows x 5 columns]

# %%
DataFrame_intelligence.drop_duplicates()
# Out:
#              Product1          Product2  supports  Confidence       Lift
# 145             pasta      pepper spray  0.002493    0.461538  23.970116
# 489          tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 420         chocolate     mineral water  0.002078    0.326087   9.019240
# 328             maggi  vegetable basket  0.002493    0.219512   7.767934
# 220           chicken              milk  0.002078    0.277778   7.653732
# ..                ...               ...       ...         ...        ...
# 123  vegetable basket             maggi  0.006095    0.215686   3.011681
# 65            chicken            paneer  0.002216    0.296296   3.004161
# 221           chicken               nan  0.002216    0.296296   3.004161
# 384            salmon               nan  0.004017    0.295918   3.000330
# 158            salmon            paneer  0.004017    0.295918   3.000330
#
# [339 rows x 5 columns]

# %%
a= DataFrame_intelligence.nlargest(10, columns= 'Lift')
a.drop_duplicates()
# Out:
#       Product1          Product2  supports  Confidence       Lift
# 145      pasta      pepper spray  0.002493    0.461538  23.970116
# 489   tomatoes  vegetable basket  0.002216    0.307692  10.888386
# 420  chocolate     mineral water  0.002078    0.326087   9.019240
# 328      maggi  vegetable basket  0.002493    0.219512   7.767934
# 220    chicken              milk  0.002078    0.277778   7.653732
# 407    chicken               nan  0.002078    0.277778   7.653732
